# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2

# %%
img =  cv2.imread(r"D:\code_python\data\images_test_sex\man\00000055.jpg")
img = cv2.cvtColor(img ,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %% [markdown]
# <hr>
# ### convert image to grayscale

# %%
gray = cv2.cvtColor(img ,cv2.COLOR_BGR2GRAY)
plt.imshow(gray,cmap='gray')

# %% [markdown]
# <hr>
# ### average black white

# %%
avg_gray = np.average(gray)
avg_gray
# Out:
# 67.59772290809327

# %%
# start_b = 1
brightness = 100
for i in range(10):
    brightness = 100 - i
    print(brightness)
# Out:
# 100
# 99
# 98
# 97
# 96
# 95
# 94
# 93
# 92
# 91

# %%
brightness
# Out:
# 100
