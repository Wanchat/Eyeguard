# %%
import csv

# %%
def angle_csv():
    with open('angle.csv') as f:
        data = csv.reader(f)
        for raw_angle in data:
            return raw_angle

# %%
def line_angle_top(point_angle):
    point_angle = float(point_angle)
    ang = [float(i) for i in angle_csv()]
    if ang[0] < point_angle <= ang[1] :
        print("ok")
        print(point_angle)
    else:
        print("no000000000")

# %%
angle_csv()
# Out:
# ['0.5',
#  '2',
#  '3.5',
#  '5.5',
#  '7',
#  '9',
#  '11',
#  '12.5',
#  '14',
#  '16',
#  '17.5',
#  '19.5',
#  '21',
#  '23',
#  '24.5',
#  '26',
#  '28',
#  '29.5',
#  '31.5',
#  '33',
#  '34.5',
#  '36.5',
#  '38',
#  '39.5',
#  '41.5',
#  '43',
#  '45',
#  '46.5',
#  '48.5',
#  '50',
#  '51.5',
#  '53',
#  '55',
#  '56.5',
#  '58.5',
#  '60',
#  '61.5',
#  '63.5',
#  '65',
#  '66.5',
#  '68.5',
#  '70',
#  '71.5',
#  '73.5',
#  '75',
#  '77',
#  '78.5',
#  '80',
#  '82',
#  '83.5',
#  '85',
#  '86.5',
#  '88.5',
#  '90',
#  '92',
#  '93.5',
#  '95',
#  '97',
#  '98.5',
#  '100',
#  '102',
#  '103.5',
#  '105',
#  '107',
#  '108.5',
#  '110',
#  '112',
#  '113.5',
#  '115',
#  '116.5',
#  '118.5',
#  '120',
#  '121.5',
#  '123.5',
#  '125',
#  '126.5',
#  '128.5',
#  '130',
#  '31.5',
#  '133',
#  '135',
#  '136.5',
#  '138',
#  '140',
#  '141.5',
#  '143',
#  '145',
#  '146.5',
#  '148',
#  '149.5',
#  '151.5',
#  '153',
#  '154.5',
#  '156.5',
#  '158',
#  '159.5',
#  '161',
# ...
