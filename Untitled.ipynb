# %%
import csv
import numpy as np

# %%
def angle_cvs():
    with open('angle_new.csv') as f:
        data = csv.reader(f)
        for raw_angle in data:
            return raw_angle

# def raw_angle():
#     return [float(i) for i in angle_cvs()]

# def newtable():
#     table = np.array(raw_angle())
#     table.shape = (14,10)
#     return table

# %%
raw_angle = [float(i) for i in angle_cvs()]

# %%
table = np.array(raw_angle)
table.shape = (14,10)

# %%
# table = newtable()
# table # สร้าง table เป็น array

# %%
table_top = np.roll(table,6)
table_top # ย้าย array
# Out:
# array([[ 220. ,  220. ,  220. ,  220. ,  220. ,  220. ,    0. ,    0.5,
#            2. ,    3.5],
#        [   5.5,    7. ,    9. ,   11. ,   12.5,   14. ,   16. ,   17.5,
#           19.5,   21. ],
#        [  23. ,   24.5,   26. ,   28. ,   29.5,   31.5,   33. ,   34.5,
#           36.5,   38. ],
#        [  39.5,   41.5,   43. ,   45. ,   46.5,   48.5,   50. ,   51.5,
#           53. ,   55. ],
#        [  56.5,   58.5,   60. ,   61.5,   63.5,   65. ,   66.5,   68.5,
#           70. ,   71.5],
#        [  73.5,   75. ,   77. ,   78.5,   80. ,   82. ,   83.5,   85. ,
#           86.5,   88.5],
#        [  90. ,   92. ,   93.5,   95. ,   97. ,   98.5,  100. ,  102. ,
#          103.5,  105. ],
#        [ 107. ,  108.5,  110. ,  112. ,  113.5,  115. ,  116.5,  118.5,
#          120. ,  121.5],
#        [ 123.5,  125. ,  126.5,  128.5,  130. ,   31.5,  133. ,  135. ,
#          136.5,  138. ],
#        [ 140. ,  141.5,  143. ,  145. ,  146.5,  148. ,  149.5,  151.5,
#          153. ,  154.5],
#        [ 156.5,  158. ,  159.5,  161. ,  163. ,  164.5,  166. ,  168. ,
#          169.5,  171. ],
#        [ 172.5,  174.5,  176. ,  177.5,  179. ,  181. ,  182.5,  184. ,
#          186. ,  187.5],
#        [ 189. ,  190.5,  192.5,  194. ,  195.5,  197. ,  199. ,  200.5,
#          202. ,  203.5],
#        [ 205.5,  207. ,  208.5,  210.5,  212. ,  213.5,  215. ,  216.5,
#          218.5,  220. ]])

# %%
table_top[0,0:6]=0
table_top # แปลงค่าไม่ใช้เป็น 0
# Out:
# array([[   0. ,    0. ,    0. ,    0. ,    0. ,    0. ,    0. ,    0.5,
#            2. ,    3.5],
#        [   5.5,    7. ,    9. ,   11. ,   12.5,   14. ,   16. ,   17.5,
#           19.5,   21. ],
#        [  23. ,   24.5,   26. ,   28. ,   29.5,   31.5,   33. ,   34.5,
#           36.5,   38. ],
#        [  39.5,   41.5,   43. ,   45. ,   46.5,   48.5,   50. ,   51.5,
#           53. ,   55. ],
#        [  56.5,   58.5,   60. ,   61.5,   63.5,   65. ,   66.5,   68.5,
#           70. ,   71.5],
#        [  73.5,   75. ,   77. ,   78.5,   80. ,   82. ,   83.5,   85. ,
#           86.5,   88.5],
#        [  90. ,   92. ,   93.5,   95. ,   97. ,   98.5,  100. ,  102. ,
#          103.5,  105. ],
#        [ 107. ,  108.5,  110. ,  112. ,  113.5,  115. ,  116.5,  118.5,
#          120. ,  121.5],
#        [ 123.5,  125. ,  126.5,  128.5,  130. ,   31.5,  133. ,  135. ,
#          136.5,  138. ],
#        [ 140. ,  141.5,  143. ,  145. ,  146.5,  148. ,  149.5,  151.5,
#          153. ,  154.5],
#        [ 156.5,  158. ,  159.5,  161. ,  163. ,  164.5,  166. ,  168. ,
#          169.5,  171. ],
#        [ 172.5,  174.5,  176. ,  177.5,  179. ,  181. ,  182.5,  184. ,
#          186. ,  187.5],
#        [ 189. ,  190.5,  192.5,  194. ,  195.5,  197. ,  199. ,  200.5,
#          202. ,  203.5],
#        [ 205.5,  207. ,  208.5,  210.5,  212. ,  213.5,  215. ,  216.5,
#          218.5,  220. ]])

# %%
table_under = table + 200
table_under # เส้นมุมล่าง table_under ย้าย array
# Out:
# array([[ 200. ,  200.5,  202. ,  203.5,  205.5,  207. ,  209. ,  211. ,
#          212.5,  214. ],
#        [ 216. ,  217.5,  219.5,  221. ,  223. ,  224.5,  226. ,  228. ,
#          229.5,  231.5],
#        [ 233. ,  234.5,  236.5,  238. ,  239.5,  241.5,  243. ,  245. ,
#          246.5,  248.5],
#        [ 250. ,  251.5,  253. ,  255. ,  256.5,  258.5,  260. ,  261.5,
#          263.5,  265. ],
#        [ 266.5,  268.5,  270. ,  271.5,  273.5,  275. ,  277. ,  278.5,
#          280. ,  282. ],
#        [ 283.5,  285. ,  286.5,  288.5,  290. ,  292. ,  293.5,  295. ,
#          297. ,  298.5],
#        [ 300. ,  302. ,  303.5,  305. ,  307. ,  308.5,  310. ,  312. ,
#          313.5,  315. ],
#        [ 316.5,  318.5,  320. ,  321.5,  323.5,  325. ,  326.5,  328.5,
#          330. ,  231.5],
#        [ 333. ,  335. ,  336.5,  338. ,  340. ,  341.5,  343. ,  345. ,
#          346.5,  348. ],
#        [ 349.5,  351.5,  353. ,  354.5,  356.5,  358. ,  359.5,  361. ,
#          363. ,  364.5],
#        [ 366. ,  368. ,  369.5,  371. ,  372.5,  374.5,  376. ,  377.5,
#          379. ,  381. ],
#        [ 382.5,  384. ,  386. ,  387.5,  389. ,  390.5,  392.5,  394. ,
#          395.5,  397. ],
#        [ 399. ,  400.5,  402. ,  403.5,  405.5,  407. ,  408.5,  410.5,
#          412. ,  413.5],
#        [ 415. ,  416.5,  418.5,  420. ,  420. ,  420. ,  420. ,  420. ,
#          420. ,  420. ]])
