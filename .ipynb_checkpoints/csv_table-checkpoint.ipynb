# %%
import csv
import numpy as np

# %%
# def angle_cvs():
#     with open('angle_new.csv') as f:
#         data = csv.reader(f)
#         for raw_angle in data:
#             return raw_angle

# def raw_angle():
#     return [float(i) for i in angle_cvs()]

# def newtable():
#     table = np.array(raw_angle())
#     table.shape = (14,10)
#     return table

# %%
angle_cvs =[]
with open('angle_new.csv') as f:
    data = csv.reader(f)
    for i in data:
        angle_cvs.append(i)

# %%
raw_angle = [float(i) for i in angle_csv()]

# %%
table = np.array(raw_angle)
table.shape = (14,10)

# %%
# table = newtable()
# table # สร้าง table เป็น array

# %%
table = np.roll(table,6)
table # ย้าย array
# Out:
# array([[ 220. ,  220. ,  220. ,  220. ,  220. ,  220. ,    0. ,    0.5,
#            2. ,    3.5],
#        [   5.5,    7. ,    9. ,   11. ,   12.5,   14. ,   16. ,   17.5,
#           19.5,   21. ],
#        [  23. ,   24.5,   26. ,   28. ,   29.5,   31.5,   33. ,   34.5,
#           36.5,   38. ],
#        [  39.5,   41.5,   43. ,   45. ,   46.5,   48.5,   50. ,   51.5,
#           53. ,   55. ],
#        [  56.5,   58.5,   60. ,   61.5,   63.5,   65. ,   66.5,   68.5,
#           70. ,   71.5],
#        [  73.5,   75. ,   77. ,   78.5,   80. ,   82. ,   83.5,   85. ,
#           86.5,   88.5],
#        [  90. ,   92. ,   93.5,   95. ,   97. ,   98.5,  100. ,  102. ,
#          103.5,  105. ],
#        [ 107. ,  108.5,  110. ,  112. ,  113.5,  115. ,  116.5,  118.5,
#          120. ,  121.5],
#        [ 123.5,  125. ,  126.5,  128.5,  130. ,   31.5,  133. ,  135. ,
#          136.5,  138. ],
#        [ 140. ,  141.5,  143. ,  145. ,  146.5,  148. ,  149.5,  151.5,
# ...

# %%
table[0,0:6]=0
table # แปลงค่าไม่ใช้เป็น 0
# Out:
# array([[   0. ,    0. ,    0. ,    0. ,    0. ,    0. ,    0. ,    0.5,
#            2. ,    3.5],
#        [   5.5,    7. ,    9. ,   11. ,   12.5,   14. ,   16. ,   17.5,
#           19.5,   21. ],
#        [  23. ,   24.5,   26. ,   28. ,   29.5,   31.5,   33. ,   34.5,
#           36.5,   38. ],
#        [  39.5,   41.5,   43. ,   45. ,   46.5,   48.5,   50. ,   51.5,
#           53. ,   55. ],
#        [  56.5,   58.5,   60. ,   61.5,   63.5,   65. ,   66.5,   68.5,
#           70. ,   71.5],
#        [  73.5,   75. ,   77. ,   78.5,   80. ,   82. ,   83.5,   85. ,
#           86.5,   88.5],
#        [  90. ,   92. ,   93.5,   95. ,   97. ,   98.5,  100. ,  102. ,
#          103.5,  105. ],
#        [ 107. ,  108.5,  110. ,  112. ,  113.5,  115. ,  116.5,  118.5,
#          120. ,  121.5],
#        [ 123.5,  125. ,  126.5,  128.5,  130. ,   31.5,  133. ,  135. ,
#          136.5,  138. ],
#        [ 140. ,  141.5,  143. ,  145. ,  146.5,  148. ,  149.5,  151.5,
# ...

# %%
table_under = np.roll(table,-6)
table_under # เส้นมุมล่าง table_under ย้าย array
# Out:
# array([[   0. ,    0.5,    2. ,    3.5,    5.5,    7. ,    9. ,   11. ,
#           12.5,   14. ],
#        [  16. ,   17.5,   19.5,   21. ,   23. ,   24.5,   26. ,   28. ,
#           29.5,   31.5],
#        [  33. ,   34.5,   36.5,   38. ,   39.5,   41.5,   43. ,   45. ,
#           46.5,   48.5],
#        [  50. ,   51.5,   53. ,   55. ,   56.5,   58.5,   60. ,   61.5,
#           63.5,   65. ],
#        [  66.5,   68.5,   70. ,   71.5,   73.5,   75. ,   77. ,   78.5,
#           80. ,   82. ],
#        [  83.5,   85. ,   86.5,   88.5,   90. ,   92. ,   93.5,   95. ,
#           97. ,   98.5],
#        [ 100. ,  102. ,  103.5,  105. ,  107. ,  108.5,  110. ,  112. ,
#          113.5,  115. ],
#        [ 116.5,  118.5,  120. ,  121.5,  123.5,  125. ,  126.5,  128.5,
#          130. ,   31.5],
#        [ 133. ,  135. ,  136.5,  138. ,  140. ,  141.5,  143. ,  145. ,
#          146.5,  148. ],
#        [ 149.5,  151.5,  153. ,  154.5,  156.5,  158. ,  159.5,  161. ,
# ...

# %%
table_under[13:14, 4:10] = 220
table_under # เส้นมุมล่าง table_under แปลง 0 เป็น 220
# Out:
# array([[   0. ,    0.5,    2. ,    3.5,    5.5,    7. ,    9. ,   11. ,
#           12.5,   14. ],
#        [  16. ,   17.5,   19.5,   21. ,   23. ,   24.5,   26. ,   28. ,
#           29.5,   31.5],
#        [  33. ,   34.5,   36.5,   38. ,   39.5,   41.5,   43. ,   45. ,
#           46.5,   48.5],
#        [  50. ,   51.5,   53. ,   55. ,   56.5,   58.5,   60. ,   61.5,
#           63.5,   65. ],
#        [  66.5,   68.5,   70. ,   71.5,   73.5,   75. ,   77. ,   78.5,
#           80. ,   82. ],
#        [  83.5,   85. ,   86.5,   88.5,   90. ,   92. ,   93.5,   95. ,
#           97. ,   98.5],
#        [ 100. ,  102. ,  103.5,  105. ,  107. ,  108.5,  110. ,  112. ,
#          113.5,  115. ],
#        [ 116.5,  118.5,  120. ,  121.5,  123.5,  125. ,  126.5,  128.5,
#          130. ,   31.5],
#        [ 133. ,  135. ,  136.5,  138. ,  140. ,  141.5,  143. ,  145. ,
#          146.5,  148. ],
#        [ 149.5,  151.5,  153. ,  154.5,  156.5,  158. ,  159.5,  161. ,
# ...

# %%
table_under = table_under + 220
table_under # เส้นมุมล่าง table_under ได้ค่าต้องการ
# Out:
# array([[ 220. ,  220.5,  222. ,  223.5,  225.5,  227. ,  229. ,  231. ,
#          232.5,  234. ],
#        [ 236. ,  237.5,  239.5,  241. ,  243. ,  244.5,  246. ,  248. ,
#          249.5,  251.5],
#        [ 253. ,  254.5,  256.5,  258. ,  259.5,  261.5,  263. ,  265. ,
#          266.5,  268.5],
#        [ 270. ,  271.5,  273. ,  275. ,  276.5,  278.5,  280. ,  281.5,
#          283.5,  285. ],
#        [ 286.5,  288.5,  290. ,  291.5,  293.5,  295. ,  297. ,  298.5,
#          300. ,  302. ],
#        [ 303.5,  305. ,  306.5,  308.5,  310. ,  312. ,  313.5,  315. ,
#          317. ,  318.5],
#        [ 320. ,  322. ,  323.5,  325. ,  327. ,  328.5,  330. ,  332. ,
#          333.5,  335. ],
#        [ 336.5,  338.5,  340. ,  341.5,  343.5,  345. ,  346.5,  348.5,
#          350. ,  251.5],
#        [ 353. ,  355. ,  356.5,  358. ,  360. ,  361.5,  363. ,  365. ,
#          366.5,  368. ],
#        [ 369.5,  371.5,  373. ,  374.5,  376.5,  378. ,  379.5,  381. ,
# ...
